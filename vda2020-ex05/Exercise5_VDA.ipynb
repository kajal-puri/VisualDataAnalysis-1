# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import seaborn as sns
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn import manifold

# %% [markdown]
# ## Exercise 1a:
#
# **a) Again read the breast-cancer-wisconsin.xlsx file from the previous sheet. Interpolate missing
# values as before, and keep all variables. We will now explore the results of t-SNE with different
# settings.**

# %%
cancer_data = pd.read_excel("/content/breast-cancer-wisconsin.xlsx")
cancer_data.head()
# Out:
#       code  thickness  uniCelS  uniCelShape  ...  blaChroma  normNuc  mitoses  class
# 0  1000025          5        1            1  ...          3        1        1      2
# 1  1002945          5        4            4  ...          3        2        1      2
# 2  1015425          3        1            1  ...          3        1        1      2
# 3  1016277          6        8            8  ...          3        7        1      2
# 4  1017023          4        1            1  ...          3        1        1      2
#
# [5 rows x 11 columns]

# %%
cancer_data.isnull().sum()
# Out:
# code            0
# thickness       0
# uniCelS         0
# uniCelShape     0
# marAdh          0
# epiCelSize      0
# bareNuc        16
# blaChroma       0
# normNuc         0
# mitoses         0
# class           0
# dtype: int64

# %% [markdown]
# We can see from above inspection that only bareNuc has 16 missing values. Rest every column has no missing value

# %%
sns.countplot(cancer_data['bareNuc'])

# %% [markdown]
# We can see from above the data distribution of each number (0-10) in the plotted graph. The frequency of 1 is more than 400 times as compared to 10 i.e. occurring only around 150 times as compared to others. So we will impute the missing 16 values with the values "1.0" as it is the most occuring value in data.

# %%
cancer_data['bareNuc'].isnull().sum()
# Out:
# 16

# %%
impute = SimpleImputer(missing_values=np.NaN, strategy='most_frequent')
data_complete = pd.DataFrame(impute.fit_transform(cancer_data))
data_complete.columns = cancer_data.columns
data_complete.index = cancer_data.index
data_complete.isnull().sum()
# Out:
# code           0
# thickness      0
# uniCelS        0
# uniCelShape    0
# marAdh         0
# epiCelSize     0
# bareNuc        0
# blaChroma      0
# normNuc        0
# mitoses        0
# class          0
# dtype: int64

# %% [markdown]
# **Ans :** We used Simple Imputer function to impute the missing data and strategy used is "most frequently" that also corresponds to "mode" in statistics because of the distribution of the data in such a manner.

# %% [markdown]
# **Run t-SNE with a random initial distribution of points and different perplexities, i.e., 5, 10,
# 20, 30, 40, and 50. Visualize the 2D data set in a scatter plot using different colors for cases
# from benign and malignant classes.**

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=5)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=10)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=20)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=30)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=40)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
N = 650
rndperm = np.random.permutation(data_complete.shape[0])
df_subset = data_complete.loc[rndperm[:N],:].copy()
data_subset = df_subset[data_complete.columns].values
tsne = TSNE(perplexity=50)
tsne_results = tsne.fit_transform(data_subset)
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %% [markdown]
# **Repeat this experiment, except this time use PCA to create the initial distribution of points.
# Note that the implementation in scikit-learn allows you to select the initialization using a
# keyword parameter.**

# %%
data_subset = df_subset[data_complete.columns].values
pca = PCA(n_components=2, svd_solver='randomized', random_state=42)
pca_result = pca.fit(data_subset)
pca_results = pca.transform(data_subset)
df_subset['PCA-2d-one'] = pca_results[:,0]
df_subset['PCA-2d-two'] = pca_results[:,1]
sns.scatterplot(
    x="PCA-2d-one", y="PCA-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
data_subset = df_subset[data_complete.columns].values
pca = PCA(n_components=5, svd_solver='randomized', random_state=42)
pca_result = pca.fit(data_subset)
pca_results = pca.transform(data_subset)
df_subset['PCA-2d-one'] = pca_results[:,0]
df_subset['PCA-2d-two'] = pca_results[:,1]
sns.scatterplot(
    x="PCA-2d-one", y="PCA-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
data_subset = df_subset[data_complete.columns].values
pca = PCA(n_components=10, svd_solver='randomized', random_state=42)
pca_result = pca.fit(data_subset)
pca_results = pca.transform(data_subset)
df_subset['PCA-2d-one'] = pca_results[:,0]
df_subset['PCA-2d-two'] = pca_results[:,1]
sns.scatterplot(
    x="PCA-2d-one", y="PCA-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %%
data_subset = df_subset[data_complete.columns].values
pca = PCA(n_components=11, svd_solver='randomized', random_state=0)
pca_result = pca.fit(data_subset)
pca_results = pca.transform(data_subset)
df_subset['PCA-2d-one'] = pca_results[:,0]
df_subset['PCA-2d-two'] = pca_results[:,1]
sns.scatterplot(
    x="PCA-2d-one", y="PCA-2d-two",
    hue="class",
    data=df_subset,
    legend="full"
)

# %% [markdown]
# On running the datasets we found that t-sne performs much better than PCA in seperating data clusters. \
#
# Within t-SNE inreasing the perplexity we get the best result i.e. for perpelexity =50

# %% [markdown]
# ## Exercise 1b:
#
# **Read the data set and interpolate missing values in a reasonable way.**

# %%
nuc_data = pd.read_excel("/content/Data_Cortex_Nuclear.xls")
nuc_data.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N  ...  Genotype  Treatment  Behavior   class
# 0   309_1  0.503644  0.747193  0.430175  ...   Control  Memantine       C/S  c-CS-m
# 1   309_2  0.514617  0.689064  0.411770  ...   Control  Memantine       C/S  c-CS-m
# 2   309_3  0.509183  0.730247  0.418309  ...   Control  Memantine       C/S  c-CS-m
# 3   309_4  0.442107  0.617076  0.358626  ...   Control  Memantine       C/S  c-CS-m
# 4   309_5  0.434940  0.617430  0.358802  ...   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
missing = nuc_data.isnull().sum()
missing
# Out:
# MouseID      0
# DYRK1A_N     3
# ITSN1_N      3
# BDNF_N       3
# NR1_N        3
#             ..
# CaNA_N       0
# Genotype     0
# Treatment    0
# Behavior     0
# class        0
# Length: 82, dtype: int64

# %%
nuclear_data = nuc_data.interpolate(method = 'linear', limit_direction='forward')
nuclear_data.isnull().sum()
# Out:
# MouseID      0
# DYRK1A_N     0
# ITSN1_N      0
# BDNF_N       0
# NR1_N        0
#             ..
# CaNA_N       0
# Genotype     0
# Treatment    0
# Behavior     0
# class        0
# Length: 82, dtype: int64

# %% [markdown]
# **How many mice were measured for each of these groups?**

# %%
nuclear_data['class'].value_counts()
# Out:
# c-CS-m    150
# c-SC-m    150
# c-SC-s    135
# c-CS-s    135
# t-CS-m    135
# t-SC-m    135
# t-SC-s    135
# t-CS-s    105
# Name: class, dtype: int64

# %%
csc = nuclear_data.loc[nuclear_data['class'] == 'c-CS-s']
csc.count()
# Out:
# MouseID      135
# DYRK1A_N     135
# ITSN1_N      135
# BDNF_N       135
# NR1_N        135
#             ...
# CaNA_N       135
# Genotype     135
# Treatment    135
# Behavior     135
# class        135
# Length: 82, dtype: int64

# %%
tsc = nuclear_data.loc[nuclear_data['class'] == 't-CS-s']
tsc.count()
# Out:
# MouseID      105
# DYRK1A_N     105
# ITSN1_N      105
# BDNF_N       105
# NR1_N        105
#             ...
# CaNA_N       105
# Genotype     105
# Treatment    105
# Behavior     105
# class        105
# Length: 82, dtype: int64

# %%
csc.columns
# Out:
# Index(['MouseID', 'DYRK1A_N', 'ITSN1_N', 'BDNF_N', 'NR1_N', 'NR2A_N', 'pAKT_N',
#        'pBRAF_N', 'pCAMKII_N', 'pCREB_N', 'pELK_N', 'pERK_N', 'pJNK_N',
#        'PKCA_N', 'pMEK_N', 'pNR1_N', 'pNR2A_N', 'pNR2B_N', 'pPKCAB_N',
#        'pRSK_N', 'AKT_N', 'BRAF_N', 'CAMKII_N', 'CREB_N', 'ELK_N', 'ERK_N',
#        'GSK3B_N', 'JNK_N', 'MEK_N', 'TRKA_N', 'RSK_N', 'APP_N', 'Bcatenin_N',
#        'SOD1_N', 'MTOR_N', 'P38_N', 'pMTOR_N', 'DSCR1_N', 'AMPKA_N', 'NR2B_N',
#        'pNUMB_N', 'RAPTOR_N', 'TIAM1_N', 'pP70S6_N', 'NUMB_N', 'P70S6_N',
#        'pGSK3B_N', 'pPKCG_N', 'CDK5_N', 'S6_N', 'ADARB1_N', 'AcetylH3K9_N',
#        'RRP1_N', 'BAX_N', 'ARC_N', 'ERBB4_N', 'nNOS_N', 'Tau_N', 'GFAP_N',
#        'GluR3_N', 'GluR4_N', 'IL1B_N', 'P3525_N', 'pCASP9_N', 'PSD95_N',
#        'SNCA_N', 'Ubiquitin_N', 'pGSK3B_Tyr216_N', 'SHH_N', 'BAD_N', 'BCL2_N',
#        'pS6_N', 'pCFOS_N', 'SYP_N', 'H3AcK18_N', 'EGR1_N', 'H3MeK4_N',
#        'CaNA_N', 'Genotype', 'Treatment', 'Behavior', 'class'],
# ...

# %%
cscf = csc.drop(['MouseID','Genotype','Treatment','Behavior','class'], axis = 1)
cscf.count()
# Out:
# DYRK1A_N     135
# ITSN1_N      135
# BDNF_N       135
# NR1_N        135
# NR2A_N       135
#             ...
# SYP_N        135
# H3AcK18_N    135
# EGR1_N       135
# H3MeK4_N     135
# CaNA_N       135
# Length: 77, dtype: int64

# %%
tscf = tsc.drop(['MouseID','Genotype','Treatment','Behavior','class'], axis = 1)
tscf.count()
# Out:
# DYRK1A_N     105
# ITSN1_N      105
# BDNF_N       105
# NR1_N        105
# NR2A_N       105
#             ...
# SYP_N        105
# H3AcK18_N    105
# EGR1_N       105
# H3MeK4_N     105
# CaNA_N       105
# Length: 77, dtype: int64

# %% [markdown]
# **Only for the mice from c-SC-s and t-SC-s classes, use PCA to reduce the 77 dimensional data
# set to two dimensions. Make sure not to include the remaining columns, which contain meta
# information. Visualize the 2D data set in a scatter plot using different colors for instances
# from each class.**

# %%
pca = PCA(n_components=2)
pca.fit(cscf)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
c_data = nuclear_data.drop(['MouseID','Genotype','Treatment','Behavior'], axis = 1)
datain = c_data.loc[(c_data['class'] == 't-SC-s') | (c_data['class'] == 'c-SC-s')]
#d1 = datain.drop(['class'], axis = 1)
l = datain['class']
l.reset_index()['class']
# Out:
# 0      c-SC-s
# 1      c-SC-s
# 2      c-SC-s
# 3      c-SC-s
# 4      c-SC-s
#         ...
# 265    t-SC-s
# 266    t-SC-s
# 267    t-SC-s
# 268    t-SC-s
# 269    t-SC-s
# Name: class, Length: 270, dtype: object

# %%
pca = PCA(n_components=2)
o = pca.fit(datain.drop(['class'], axis = 1))
ok = pca.transform(datain.drop(['class'], axis = 1))

# %%
twocomponents = pd.DataFrame(data = ok, columns = ['P.Component 1', 'P.Component 2'])

twocomponents['classes'] = l.reset_index()['class']
#twocomponents['class'].replace(0,'t-CS-s',inplace=True)
#twocomponents['class'].replace(1,'c-CS-s',inplace=True)
twocomponents
#twocomponents
# Out:
#      P.Component 1  P.Component 2 classes
# 0         0.951751       0.509402  c-SC-s
# 1         0.991788       0.495075  c-SC-s
# 2         1.094334       0.607684  c-SC-s
# 3         0.265340       0.282920  c-SC-s
# 4         0.438033       0.347669  c-SC-s
# ..             ...            ...     ...
# 265      -1.933212      -0.594581  t-SC-s
# 266      -1.738083      -0.478868  t-SC-s
# 267      -2.841926      -0.813803  t-SC-s
# 268      -2.567466      -0.709054  t-SC-s
# 269      -2.022684      -0.591514  t-SC-s
#
# [270 rows x 3 columns]

# %%
sns.pairplot(twocomponents,hue="classes",vars=twocomponents.columns.drop("classes"))

# %%
#plt.scatter(twocomponents['P.Component 1'], twocomponents['P.Component 2', c=twocomponents['class'])#, edgecolor='', alpha=0.5)
ax = sns.scatterplot(x = twocomponents['P.Component 1'], y = twocomponents["classes"])
plt.show()

# %% [markdown]
# **Produce a corresponding plot with ISOMAP. Try different values for the number of neighbors
# when constructing the neighborhood graph. Can you find a setting that separates the groups
# more clearly than PCA?**

# %%
iso = manifold.Isomap(n_neighbors=8, n_components=2)
d1 = datain.drop(['class'], axis = 1)
iso.fit(d1)
manifold_2Da = iso.transform(d1)
manifold_2D = pd.DataFrame(manifold_2Da, columns=['P.Component 1', 'P.Component 2'])
manifold_2D['classes'] = l.reset_index()['class']
manifold_2D
# Out:
#      P.Component 1  P.Component 2 classes
# 0        -3.591192      -2.699959  c-SC-s
# 1        -3.607797      -2.726927  c-SC-s
# 2        -3.780036      -2.947641  c-SC-s
# 3        -2.915751      -2.486416  c-SC-s
# 4        -2.996187      -2.544272  c-SC-s
# ..             ...            ...     ...
# 265       0.381844       4.527294  t-SC-s
# 266       0.740623       4.474035  t-SC-s
# 267      -0.663902       5.009221  t-SC-s
# 268      -0.600792       4.616452  t-SC-s
# 269       0.296936       4.620201  t-SC-s
#
# [270 rows x 3 columns]

# %%
sns.pairplot(manifold_2D,hue="classes",vars=manifold_2D.columns.drop("classes"))

# %% [markdown]
# **Finally, try t-SNE with different settings. Does this allow you to separate the groups better
# than with PCA or ISOMAP?**
#
# And : Yes, tsne seems to be working best

# %%
tsne = TSNE(n_components=2,perplexity=10)
tsne_results = tsne.fit_transform(datain.drop(['class'], axis = 1))
tsne_data = pd.DataFrame(tsne_results, columns=['P.Component 1', 'P.Component 2'])
tsne_data['classes'] = l.reset_index()['class']

# %%
sns.pairplot(tsne_data,hue="classes",vars=tsne_data.columns.drop("classes"))

# %%
tsne = TSNE(n_components=2,perplexity=50)
tsne_results = tsne.fit_transform(datain.drop(['class'], axis = 1))
tsne_data = pd.DataFrame(tsne_results, columns=['P.Component 1', 'P.Component 2'])
tsne_data['classes'] = l.reset_index()['class']
sns.pairplot(tsne_data,hue="classes",vars=tsne_data.columns.drop("classes"))

# %%
tsne = TSNE(n_components=2,perplexity=30)
tsne_results = tsne.fit_transform(datain.drop(['class'], axis = 1))
tsne_data = pd.DataFrame(tsne_results, columns=['P.Component 1', 'P.Component 2'])
tsne_data['classes'] = l.reset_index()['class']
sns.pairplot(tsne_data,hue="classes",vars=tsne_data.columns.drop("classes"))

# %%
tsne = TSNE(n_components=2,perplexity=5)
tsne_results = tsne.fit_transform(datain.drop(['class'], axis = 1))
tsne_data = pd.DataFrame(tsne_results, columns=['P.Component 1', 'P.Component 2'])
tsne_data['classes'] = l.reset_index()['class']
sns.pairplot(tsne_data,hue="classes",vars=tsne_data.columns.drop("classes"))
